# %% [markdown]
# R environment

# %%
library(Seurat)
library(dplyr)
library(cowplot)
library(ggplot2)
library(copykat)
library(patchwork)
library(future)
source("modified_copykat.R")
plan("multiprocess", workers = 12)
options(future.globals.maxSize = 10000 * 1024^10,
        future.rng.onMisuse = 'ignore')
sessionInfo()
# Out:
# Attaching SeuratObject
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
# R version 4.0.3 (2020-10-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /hpc/pmc_stunnenberg/cruiz/miniconda3/envs/r_pHGG_project/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] future_1.21.0      patchwork_1.1.1    copykat_1.0.4      ggplot2_3.3.3
# [5] cowplot_1.1.1      dplyr_1.0.6        SeuratObject_4.0.1 Seurat_4.0.1.9005
#
# loaded via a namespace (and not attached):
#   [1] nlme_3.1-152          spatstat.sparse_2.0-0 matrixStats_0.58.0
#   [4] RcppAnnoy_0.0.18      RColorBrewer_1.1-2    httr_1.4.2
#   [7] repr_1.1.3            sctransform_0.3.2     tools_4.0.3
#  [10] utf8_1.2.1            R6_2.5.0              irlba_2.3.3
#  [13] rpart_4.1-15          KernSmooth_2.23-20    uwot_0.1.10
#  [16] mgcv_1.8-35           DBI_1.1.1             lazyeval_0.2.2
#  [19] colorspace_2.0-1      withr_2.4.2           tidyselect_1.1.1
#  [22] gridExtra_2.3         compiler_4.0.3        plotly_4.9.3
#  [25] scales_1.1.1          spatstat.data_2.1-0   lmtest_0.9-38
#  [28] ggridges_0.5.3        pbapply_1.4-3         goftest_1.2-2
#  [31] pbdZMQ_0.3-5          stringr_1.4.0         digest_0.6.27
#  [34] spatstat.utils_2.1-0  base64enc_0.1-3       pkgconfig_2.0.3
#  [37] htmltools_0.5.1.1     parallelly_1.25.0     fastmap_1.1.0
#  [40] htmlwidgets_1.5.3     rlang_0.4.11          shiny_1.6.0
#  [43] generics_0.1.0        zoo_1.8-9             jsonlite_1.7.2
#  [46] ica_1.0-2             magrittr_2.0.1        Matrix_1.3-3
#  [49] Rcpp_1.0.6            IRkernel_1.1.1        munsell_0.5.0
#  [52] fansi_0.4.2           abind_1.4-5           reticulate_1.19
#  [55] lifecycle_1.0.0       stringi_1.5.3         MASS_7.3-54
#  [58] Rtsne_0.15            plyr_1.8.6            grid_4.0.3
#  [61] parallel_4.0.3        listenv_0.8.0         promises_1.2.0.1
#  [64] ggrepel_0.9.1         crayon_1.4.1          deldir_0.2-10
#  [67] miniUI_0.1.1.1        lattice_0.20-44       IRdisplay_1.0
#  [70] splines_4.0.3         tensor_1.5            pillar_1.6.0
#  [73] igraph_1.2.6          uuid_0.1-4            spatstat.geom_2.1-0
#  [76] future.apply_1.7.0    reshape2_1.4.4        codetools_0.2-18
#  [79] leiden_0.3.7          glue_1.4.2            evaluate_0.14
#  [82] data.table_1.14.0     vctrs_0.3.8           png_0.1-7
#  [85] httpuv_1.6.0          polyclip_1.10-0       spatstat.core_2.1-2
#  [88] gtable_0.3.0          RANN_2.6.1            purrr_0.3.4
#  [91] tidyr_1.1.3           scattermore_0.7       assertthat_0.2.1
#  [94] mime_0.10             xtable_1.8-4          later_1.2.0
#  [97] survival_3.2-11       viridisLite_0.4.0     tibble_3.1.1
# [100] cluster_2.1.2         globals_0.14.0        fitdistrplus_1.1-3
# [103] ellipsis_0.3.2        ROCR_1.0-11

# %%
reference.list <- readRDS('data/GBM_all_ref_no-merged_after-inclusion-criteria_alternative.rds')
reference.list
# Out:
# $Yuan2018
# An object of class Seurat
# 28951 features across 12202 samples within 1 assay
# Active assay: RNA (28951 features, 0 variable features)
#
# $Neftel2019_10x
# An object of class Seurat
# 22966 features across 13288 samples within 1 assay
# Active assay: RNA (22966 features, 0 variable features)
#
# $Neftel2019_smart
# An object of class Seurat
# 21718 features across 5742 samples within 1 assay
# Active assay: RNA (21718 features, 0 variable features)
#
# $Wang2019
# An object of class Seurat
# 38129 features across 23531 samples within 1 assay
# Active assay: RNA (38129 features, 0 variable features)
#
# $Wang2020
# An object of class Seurat
# 17566 features across 12437 samples within 1 assay
# Active assay: RNA (17566 features, 0 variable features)
#
# $Zhao2020
# An object of class Seurat
# 18774 features across 5182 samples within 1 assay
# Active assay: RNA (18774 features, 0 variable features)
#
# $Bhaduri2020
# An object of class Seurat
# 22183 features across 14934 samples within 1 assay
# Active assay: RNA (22183 features, 0 variable features)
#
# $Yu2020
# An object of class Seurat
# 22255 features across 4693 samples within 1 assay
# Active assay: RNA (22255 features, 0 variable features)
#
# $Wu2020
# An object of class Seurat
# 25439 features across 10211 samples within 1 assay
# Active assay: RNA (25439 features, 0 variable features)
#
# $Couturier2020
# An object of class Seurat
# 24019 features across 65588 samples within 1 assay
# Active assay: RNA (24019 features, 0 variable features)
#
# $Johnson2020
# An object of class Seurat
# 22964 features across 29234 samples within 1 assay
# Active assay: RNA (22964 features, 0 variable features)
#
# $Richards2021
# An object of class Seurat
# 20586 features across 79178 samples within 1 assay
# Active assay: RNA (20586 features, 0 variable features)
#
# $Darmanis2017
# An object of class Seurat
# 19894 features across 3533 samples within 1 assay
# Active assay: RNA (19894 features, 0 variable features)
#
# $Sankowski2019
# An object of class Seurat
# 14398 features across 2139 samples within 1 assay
# Active assay: RNA (14398 features, 0 variable features)
#
# $Goswami2019
# An object of class Seurat
# 14083 features across 5997 samples within 1 assay
# Active assay: RNA (14083 features, 0 variable features)
#
# $Pombo2021
# An object of class Seurat
# 18370 features across 79981 samples within 1 assay
# Active assay: RNA (18370 features, 0 variable features)
#
# $Mathewson2021
# An object of class Seurat
# 16270 features across 24310 samples within 1 assay
# Active assay: RNA (16270 features, 0 variable features)
#
# $Ruiz2021
# An object of class Seurat
# 27102 features across 39355 samples within 1 assay
# Active assay: RNA (27102 features, 0 variable features)

# %%
tmp <- merge(reference.list[[1]], y = unlist(reference.list[2:length(reference.list)]), project = "GBM", merge.data = T)

# Output a logical vector for every gene on whether the more than zero counts per cell
# Extract counts
counts <- GetAssayData(object = tmp, slot = "counts") 

# Output a logical vector for every gene on whether the more than zero counts per cell
nonzero <- counts > 0

# Sums all TRUE values and returns TRUE if more than 1000 TRUE values per gene
keep_genes <- Matrix::rowSums(nonzero) >= 100

# Only keeping those genes expressed in more than 1000 cells
filtered_counts <- counts[keep_genes, ]

# Read metadata
meta_all <- readRDS('data/core_GBmap_metadata.rds')
meta_all <- meta_all %>% mutate(celltype_assigned = read.csv('data/assigned_cellID_celltypes_core_GBmap.csv')$celltype_assigned)

# Reassign to filtered Seurat object
tmp <- CreateSeuratObject(filtered_counts, meta.data = meta_all)

# %%
reference.list <- SplitObject(tmp, split.by = 'author')
# filter out datasets with only immune cells
non.immune <- reference.list[names(reference.list) %in% c('Sankowski2019','Goswami2019','Pombo2021','Mathewson2021') == FALSE] 
rm(reference.list)
rm(tmp)
non.immune
# Out:
# $Yuan2018
# An object of class Seurat
# 36498 features across 12202 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Neftel2019_10x
# An object of class Seurat
# 36498 features across 13288 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Neftel2019_smart
# An object of class Seurat
# 36498 features across 5742 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Wang2019
# An object of class Seurat
# 36498 features across 23531 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Wang2020
# An object of class Seurat
# 36498 features across 12437 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Zhao2020
# An object of class Seurat
# 36498 features across 5182 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Bhaduri2020
# An object of class Seurat
# 36498 features across 14934 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Yu2020
# An object of class Seurat
# 36498 features across 4693 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Wu2020
# An object of class Seurat
# 36498 features across 10211 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Couturier2020
# An object of class Seurat
# 36498 features across 65588 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Johnson2020
# An object of class Seurat
# 36498 features across 29234 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Richards2021
# An object of class Seurat
# 36498 features across 79178 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Darmanis2017
# An object of class Seurat
# 36498 features across 3533 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Ruiz2021
# An object of class Seurat
# 36498 features across 39355 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)

# %%
# run first seven datsets
non.immune <- tail(non.immune, n = 4)
non.immune
# Out:
# $Johnson2020
# An object of class Seurat
# 36498 features across 29234 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Richards2021
# An object of class Seurat
# 36498 features across 79178 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Darmanis2017
# An object of class Seurat
# 36498 features across 3533 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $Ruiz2021
# An object of class Seurat
# 36498 features across 39355 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)

# %%
gbm <- merge(non.immune[[1]], y = unlist(non.immune[2:length(non.immune)]), project = "GBM", merge.data = T)
rm(non.immune)
gbm
per.sample <- SplitObject(gbm, split.by = 'patient')
rm(gbm)
head(per.sample)
# Out:
# An object of class Seurat
# 36498 features across 151300 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
# $SM006
# An object of class Seurat
# 36498 features across 5805 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $SM011
# An object of class Seurat
# 36498 features across 5453 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $SM012
# An object of class Seurat
# 36498 features across 6890 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $SM017
# An object of class Seurat
# 36498 features across 8116 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $SM018
# An object of class Seurat
# 36498 features across 2970 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)
#
# $G1003
# An object of class Seurat
# 36498 features across 9376 samples within 1 assay
# Active assay: RNA (36498 features, 0 variable features)

# %%
copykat_dir <- "copykat_output_ref_normal_cells_part_II"

ifelse(!dir.exists(copykat_dir), dir.create(copykat_dir), FALSE)
setwd(copykat_dir)

for(i in 1:length(per.sample)){
    
    cat(' #####################################\n',
      '### Processing patient', names(per.sample[i]), '###\n',
      '#####################################\n')
    
    copykat.gbm <- try(modif_copykat(rawmat=GetAssayData(per.sample[[i]], slot = 'counts'), id.type="S", ngene.chr=1, 
                           win.size=25, KS.cut=0.1, sam.name=names(per.sample[i]), distance="euclidean",
                           norm.cell.names=colnames(subset(per.sample[[i]], subset = celltype_assigned == c('Oligo') |
                                 celltype_assigned == c('TAM') |
                                 celltype_assigned == c('TIL') |
                                 celltype_assigned == c('Peri') |
                                 celltype_assigned == c('Endo'))), 
                                     n.cores=12))
    
    if (class(copykat.gbm) == "try-error") {
                        cat("Caught an error during modif_copykat, Setting less stringent cutoff.\n")
                        copykat.gbm <- modif_copykat(rawmat=GetAssayData(per.sample[[i]], slot = 'counts'), id.type="S", ngene.chr=1, 
                           win.size=25, KS.cut=0.1, sam.name=names(per.sample[i]), distance="euclidean",LOW.DR=0.01,
                           norm.cell.names=colnames(subset(per.sample[[i]], subset = celltype_assigned == c('Oligo') |
                                 celltype_assigned == c('TAM') |
                                 celltype_assigned == c('TIL') |
                                 celltype_assigned == c('Peri') |
                                 celltype_assigned == c('Endo'))), 
                                                     n.cores=12)
        }
        
    pred.gbm <- data.frame(copykat.gbm$prediction)
    CNA.gbm <- data.frame(copykat.gbm$CNAmat)
    per.sample[[i]]@misc$CNA <- CNA.gbm
    pred.gbm['cell.names'] <- NULL
    per.sample[[i]]$predCNA <- pred.gbm
}
# Out:
# [1] TRUE
#  #####################################
#  ### Processing patient SM006 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5805 cells in raw data"
# [1] "10677 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "2102 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# Warning message in .recacheSubclasses(def@className, def, env):
# “undefined subclass "numericVector" of class "Mnumeric"; definition not updated”
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 54.12976 mins
#  #####################################
#  ### Processing patient SM011 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5453 cells in raw data"
# [1] "11731 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "882 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 48.83508 mins
#  #####################################
#  ### Processing patient SM012 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 6890 cells in raw data"
# [1] "11513 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1293 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 1.262878 hours
#  #####################################
#  ### Processing patient SM017 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 8116 cells in raw data"
# [1] "11037 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1962 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 1.761187 hours
#  #####################################
#  ### Processing patient SM018 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 2970 cells in raw data"
# [1] "12170 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1905 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 18.82046 mins
#  #####################################
#  ### Processing patient G1003 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 9376 cells in raw data"
# [1] "11897 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "2286 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 2.552364 hours
#  #####################################
#  ### Processing patient G523 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5558 cells in raw data"
# [1] "8153 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "944 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 47.24424 mins
#  #####################################
#  ### Processing patient G549 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 4964 cells in raw data"
# [1] "9170 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "959 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 40.71033 mins
#  #####################################
#  ### Processing patient G566 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3983 cells in raw data"
# [1] "8836 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "867 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 29.29197 mins
#  #####################################
#  ### Processing patient G583 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5134 cells in raw data"
# [1] "9634 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "592 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 43.10486 mins
#  #####################################
#  ### Processing patient G620 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 867 cells in raw data"
# [1] "10488 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "307 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 4.394248 mins
#  #####################################
#  ### Processing patient G637 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3342 cells in raw data"
# [1] "5123 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "217 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 19.19417 mins
#  #####################################
#  ### Processing patient G729 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 4969 cells in raw data"
# [1] "8198 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1318 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 38.23132 mins
#  #####################################
#  ### Processing patient G797 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 1174 cells in raw data"
# [1] "6102 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "76 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 5.107428 mins
#  #####################################
#  ### Processing patient G799 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5709 cells in raw data"
# [1] "5852 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "326 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 47.85715 mins
#  #####################################
#  ### Processing patient G837 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 1373 cells in raw data"
# [1] "5472 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "512 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 6.154468 mins
#  #####################################
#  ### Processing patient G851 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 2487 cells in raw data"
# [1] "5420 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "215 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 12.54936 mins
#  #####################################
#  ### Processing patient G910 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 6965 cells in raw data"
# [1] "7798 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "5753 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 1.210448 hours
#  #####################################
#  ### Processing patient G945 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3219 cells in raw data"
# [1] "7873 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "761 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 18.35601 mins
#  #####################################
#  ### Processing patient G946 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3323 cells in raw data"
# [1] "5771 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "2909 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 19.22771 mins
#  #####################################
#  ### Processing patient G967 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 10858 cells in raw data"
# [1] "6685 genes past LOW.DR filtering"
# [1] "WARNING: low data quality; assigned LOW.DR to UP.DR..."
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "10118 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 3.222008 hours
#  #####################################
#  ### Processing patient G983 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5877 cells in raw data"
# [1] "10445 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "4822 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 58.7731 mins
#  #####################################
#  ### Processing patient BT_S2 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 1156 cells in raw data"
# [1] "12188 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "433 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 5.585332 mins
#  #####################################
#  ### Processing patient BT_S1 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 488 cells in raw data"
# [1] "9226 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "231 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 2.798749 mins
#  #####################################
#  ### Processing patient BT_S4 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 1507 cells in raw data"
# [1] "10378 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1138 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 6.736122 mins
#  #####################################
#  ### Processing patient BT_S6 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 382 cells in raw data"
# [1] "11520 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "232 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 2.718545 mins
#  #####################################
#  ### Processing patient NH16-2366 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 1872 cells in raw data"
# [1] "10311 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1544 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 8.870027 mins
#  #####################################
#  ### Processing patient NH17-1245 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 880 cells in raw data"
# [1] "11596 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "707 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 4.270075 mins
#  #####################################
#  ### Processing patient NH17-1258 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3521 cells in raw data"
# [1] "8359 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "3168 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 20.89662 mins
#  #####################################
#  ### Processing patient NH17-161 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 4357 cells in raw data"
# [1] "11604 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1381 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 32.26425 mins
#  #####################################
#  ### Processing patient NH17-1953 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3400 cells in raw data"
# [1] "11230 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1237 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 20.75758 mins
#  #####################################
#  ### Processing patient NH17-2069 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3509 cells in raw data"
# [1] "8569 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1529 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 20.63133 mins
#  #####################################
#  ### Processing patient NH17-2680 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3549 cells in raw data"
# [1] "10167 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "660 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 22.61408 mins
#  #####################################
#  ### Processing patient NH17-442 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5675 cells in raw data"
# [1] "10127 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "4822 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 49.51722 mins
#  #####################################
#  ### Processing patient NH18-1406 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 3939 cells in raw data"
# [1] "12830 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1427 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 28.52886 mins
#  #####################################
#  ### Processing patient NH19-123 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 2979 cells in raw data"
# [1] "12012 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "1643 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 17.36197 mins
#  #####################################
#  ### Processing patient NH19-565 ###
#  #####################################
# [1] "running copykat v1.0.4"
# [1] "step1: read and filter data ..."
# [1] "36498 genes, 5674 cells in raw data"
# [1] "11362 genes past LOW.DR filtering"
# [1] "step 2: annotations gene coordinates ..."
# [1] "start annotation ..."
# [1] "step 3: smoothing data with dlm ..."
# [1] "step 4: measuring baselines ..."
# [1] "3381 known normal cells found in dataset"
# [1] "run with known normal..."
# [1] "baseline is from known input"
# [1] "step 5: segmentation..."
# [1] "step 6: convert to genomic bins..."
# [1] "step 7: adjust baseline ..."
# [1] "step 8: final prediction ..."
# [1] "step 9: saving results..."
# [1] "step 10: ploting heatmap ..."
# Time difference of 49.17052 mins

# %%
saveRDS(per.sample, 'data/copykat_ref_normal_cells_part_II.rds')
